# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
v1=np.array([3,5])
v2=np.array([4,2])
v1v2= v1 + v2

# %%
norm_v1 = np.linalg.norm(v1)
norm_v2 = np.linalg.norm(v2)
norm_v1v2 = np.linalg.norm(v1v2)
#comprobando la desigualdad  triangular
print(norm_v1, norm_v2, norm_v1v2, norm_v1v2 <= norm_v1 + norm_v2)
# Out:
# 5.830951894845301 4.47213595499958 9.899494936611665 True

# %%
v1 = np.array([0,0,3,5])
v2 = np.array([0,0,4,2])

v1_aux = np.array([v1[2],v1[3],v2[2],v2[3]])
v1v2 = np.array([0,0,7,7])

plt.quiver([v1[0], v1_aux[0], v1v2[0]],
           [v1[1], v1_aux[1], v1v2[1]],
           [v1[2], v1_aux[2], v1v2[2]],
           [v1[3], v1_aux[3], v1v2[3]],
           angles='xy', scale_units='xy', scale =1, 
           color= sns.color_palette()
)       
plt.xlim(0,7)
plt.ylim(0,7)
# Out:
# (0.0, 7.0)
