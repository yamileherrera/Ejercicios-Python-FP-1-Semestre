# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
v1 =np.array([0,3])
v2 =np.array([3,3])

# %%
norm_v1 = np.linalg.norm(v1)
norm_v2 = np.linalg.norm(v2)
print(norm_v1, norm_v2)
# Out:
# 3.0 4.242640687119285
