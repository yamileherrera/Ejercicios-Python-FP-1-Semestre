# %%
import pandas as pd

# %%
notaFundamentos=pd.DataFrame({'Nombre':['andres','sebastian','laura','camila'],'semestre':[2,3,3,2]})
notaFundamentos
# Out:
#       Nombre  semestre
# 0     andres         2
# 1  sebastian         3
# 2      laura         3
# 3     camila         2

# %%
#insert para agregar datos
notaFundamentos.insert(2,'Ciudad',['Manizales','Pereira','Manizales','Pereira'])

# %%
notaFundamentos
# Out:
#       Nombre  semestre     Ciudad
# 0     andres         2  Manizales
# 1  sebastian         3    Pereira
# 2      laura         3  Manizales
# 3     camila         2    Pereira

# %%
#añadir valores diferentes haciendo uso del metodo operador 
notaFundamentos['Nota1']=[4,4,4,4]

# %%
notaFundamentos['Nota2']=[3,5,4,4]

# %%
notaFundamentos
# Out:
#       Nombre  semestre     Ciudad  Nota1  Nota2
# 0     andres         2  Manizales      4      3
# 1  sebastian         3    Pereira      4      5
# 2      laura         3  Manizales      4      4
# 3     camila         2    Pereira      4      4

# %%
#añadir filas a nuestro Df loc, append
notaFundamentos.loc[4]=['Maria',2,'Manizales',5,4]

# %%
notaFundamentos
# Out:
#       Nombre  semestre     Ciudad  Nota1  Nota2
# 0     andres         2  Manizales      4      3
# 1  sebastian         3    Pereira      4      5
# 2      laura         3  Manizales      4      4
# 3     camila         2    Pereira      4      4
# 4      Maria         2  Manizales      5      4

# %%
#append
notaFundamentos.append({'semestre':2,'Nota1':3,'Nombre':'Lucia','Ciudad':'Armenia','Nota2':5},ignore_index=True)
# Out:
#       Nombre  semestre     Ciudad  Nota1  Nota2
# 0     andres         2  Manizales      4      3
# 1  sebastian         3    Pereira      4      5
# 2      laura         3  Manizales      4      4
# 3     camila         2    Pereira      4      4
# 4      Maria         2  Manizales      5      4
# 5      Lucia         2    Armenia      3      5

# %%
#modificar datos iloc
notaFundamentos.iloc[2,2]='Pereira'

# %%
notaFundamentos
# Out:
#       Nombre  semestre     Ciudad  Nota1  Nota2
# 0     andres         2  Manizales      4      3
# 1  sebastian         3    Pereira      4      5
# 2      laura         3    Pereira      4      4
# 3     camila         2    Pereira      4      4
# 4      Maria         2  Manizales      5      4

# %%
notaFundamentos.iloc[2,3]=5

# %%
notaFundamentos
# Out:
#       Nombre  semestre     Ciudad  Nota1  Nota2
# 0     andres         2  Manizales      4      3
# 1  sebastian         3    Pereira      4      5
# 2      laura         3    Pereira      5      4
# 3     camila         2    Pereira      4      4
# 4      Maria         2  Manizales      5      4

# %%
#Agrupacion de datos
