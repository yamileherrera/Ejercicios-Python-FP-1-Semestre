# %%
x = 1
x
# Out:
# 1

# %%
y= "hola"
y
# Out:
# 'hola'

# %% [markdown]
# las variables, no puede tener caracteres especiales, no puede empezar por numeros, no colocar acentos segun idioma, no utilizar palabras claves de python
# por ejemplo (det), recomendacion llamarlas de una manera logica, coherente para la comprension del documento.
# sin espacios en el nombre de la variable,
#
# camelCase:  nombreMascota
#
# PascalCase: NombreMascota
#
# snake_case: nombre_mascota
#
# kebab-case: nombre-mascota.
#
# establecer el que mas te gusta, nomenclatura para hablar el mismo idioma

# %% [markdown]
# palabras reservadas por python

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# declarando multiples variables en una sola linea

# %%
age, name = 22, "maria"

# %%
age
# Out:
# 22

# %%
x= 3
x+1
# Out:
# 4

# %%
y=x+1
y
# Out:
# 4

# %%
x=x+1
x
# Out:
# 4

# %%
x=x+1
x
# Out:
# 5

# %%
x=7
x
# Out:
# 7

# %%
x+=2
x
# Out:
# 9

# %%
x *=5
x
# Out:
# 45

# %%
x-=5
x
# Out:
# 40

# %% [markdown]
# comentarios
# color verde y no se ejecutan

# %%
# no se ejecutan, permite tener texto en medio de nuestro codigo 
# vamos a definir la variable
x=1 #aqui esta nuestra variable
x
# Out:
# 1

# %% [markdown]
# algoritmo: es un conjunto ordenado de operaciones sistematicas, permite el calculo y halla solucion a un problema
# funcion: es bloque de codigo al cual le damos un nombre, recibe varios serie parametrosde entrada, sigue una secuencia de instruciones de sentencias que ejecutan la operacion deseada y devuelve un valor o realiza una tarea.
# script. archivo diseñado para ser ejecutado, se guarda las funciones, programas
# modulo script que contiene coleccion de funciones, definiciones y declaraciones de python.
#
# las funciones de un modulo puede ser importadas. con la funcion import
# ejemplo  math,

# %%
import math #cambio nombre de la libreria

# %%
import math as mt

# %%
from math import pi # solo cargo lo que necesito de la libreria (se usa directamente en este casi pi)

# %%
pi
# Out:
# 3.141592653589793

# %%
from math import pi as numero_pi # alias a la funcion pi

# %%
from math import pi, log, exp # cargar varias funciones de la libreria

# %%
from math import * # importa toda la libreria, no se recomienda ya que dos funciones de diferentes modulos tengan el mismo nombre, y diferentes en ejecucion

# %%
name ="yamile"
age = 26
pet = True
pet_name ="pyo"
ocupacion = "ingeniera"
coins = 0

# %%
coins += 100
coins
# Out:
# 100

# %% [markdown]
# TEMA 2 : NUMEROS EN PYTHON

# %%
int : numero entero, para contar y numerar 
float: es un numero con decimales, 
si dudamos si est entero o con decimales podemos utilizar 
type :(5)  
type :(5.o)

# %%
type(9.0)
# Out:
# float

# %%
type(9)
# Out:
# int

# %% [markdown]
# puedo convertir numero foat a int y viceversa
#
# **cuidado** es sencillo pasar enteros a numeros en coma flotante , ya que siempre es posible pero no siempre podemos pasar de numeros en coma flotante a numeros enteros . **pues se pierde la parte decimal**

# %%
type(int(7.0))
# Out:
# int

# %%
int(7.0)
# Out:
# 7

# %%
type(float(3)) # Hallar decimales
# Out:
# float

# %%
int(8.9) # pierde la informacion decimal no redondea, corta la parte decimal
# Out:
# 8

# %% [markdown]
# suma de numeros

# %%
2+1
# Out:
# 3

# %%
2.0+1 # sumar numero entero con un decimal, el sistema lo interpreta como numero float
# Out:
# 3.0

# %% [markdown]
# Resta de numeros

# %%
7-3
# Out:
# 4

# %%
1.0-3.
# Out:
# -2.0

# %% [markdown]
# multiplicacion

# %%
8*6
# Out:
# 48

# %%
8.*6.
# Out:
# 48.0

# %%
8.*6
# Out:
# 48.0

# %%
division #exepcion dos numeros enteros si puede dar un numero float

# %%
6/5
# Out:
# 1.2

# %%
6./5.
# Out:
# 1.2

# %%
int(6/3)
# Out:
# 2

# %% [markdown]
# Division entera o euclidea
# dado dos numeros naturaloes a y b, con b ≠ (0). la division euclidea de a entre b asocia un cociente q y el resto r. ambos numeros naturales que satisfacen
# a = b.q+r
# r<b

# %% [markdown]
# ejemplo: division entre a=7 entre b=5, tendremos que el cociente es q=1 y el resto r=2, ya que  7=5.1+2
# y el resto r es menor que al divisor b, es decir 2<5

# %% [markdown]
# para obtener el cociente de la division entera, utilizamos la funcion //

# %%
10//3 # resultado entero (int)
# Out:
# 3

# %%
10/3 # resultado numero decimal (float)
# Out:
# 3.3333333333333335

# %% [markdown]
# para obtener el resto de la division entera, utilizamos la funcion %

# %%
10 % 3 #
# Out:
# 1
