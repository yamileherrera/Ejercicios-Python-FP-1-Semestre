# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
vec1 =np.array([2,3])
vec2 =np.array([2,-4/3])
print(vec2)
# Out:
# [ 2.         -1.33333333]

# %%
product_p =int(vec1@vec2.T)
print(product_p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d392c9464318> in <module>()
# ----> 1 product_p =int(vec1@vec2.T)
#       2 print(product_p)
#
# NameError: name 'vec1' is not defined
