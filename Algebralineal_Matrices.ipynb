# %%
import numpy as np

# %%
A = np.array([[1,-2,5],[3,3,-1],[0,4,-2]])

print(A)
# Out:
# [[ 1 -2  5]
#  [ 3  3 -1]
#  [ 0  4 -2]]

# %%
det_A = np.linalg.det (A)
print(det_A)
# Out:
# 46.0

# %%
B= np.array([[2,-2,2],[2,1,0],[3,-2,2]])
B
# Out:
# array([[ 2, -2,  2],
#        [ 2,  1,  0],
#        [ 3, -2,  2]])

# %%
det_B = np.linalg.det (B)
print(det_B)
# Out:
# -2.0000000000000004
