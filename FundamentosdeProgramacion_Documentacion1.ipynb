# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Feb 18 21:37:48 2021

@author: Yamile Herrera
"""

print("ingrese 3 numeros enteros diferenetes") # informacion que se le aparece al usuario 
e = int(input("elija 1 si lo quiere de mayor a menor y 2 si lo quiere de menor a mayor")) # primera decision que toma el usuario dependiendo lo que necesite
a = int(input("ingrese el numero a")) # primera variable ingresada por el usuario 
b = int(input("ingrese el numero b")) # segunda variable ingresada por el usuario 
c = int(input("ingrese el numero c")) # tercera variable ingresada por el usuario 



if (e == 1):  # primera condicion, variable igual a uno 
    if (a > b): # condicion, variable (a) es mayor a la variable (b)
        if (a > c): # condicion, variable (a) es mayor a la variable (c)
            if (b > c): # condicion, variable (b) es mayor a la variable (c) 

               print(a, b, c) # si esto se cumple muestre las variables(a,b,c) al usuario
            else: # de lo contrario 
               print(a, c, b)  # muestre las variables (a,c,b) al usuario

    if (c > a): # condicion, variable (c) mayor (a)
        if (c > b): # condicion, variable (c) mayor (b)
            if (b > a):# condicion, variable (b) mayor (a)
               print(c, b, a) # si esto se cumple muestre las variables (c,b,a) al usuario
            else: # de lo contrario
               print(c, a, b) # muestre las variables (c, a, b) al usuario 
               

    if (b > a):# condicion, variable (b) mayor (a)
        if (b > c):# condicion, variable (b) mayor (c)
            if (a > c):# condicion, variable (a) mayor (c)
               print(b, a, c) # si esto se cumple muestre las variables(b, a, c) al usuario
            else:# de lo contrario
               print(b, c, a) # muestre las variables (b, c, a) al usuario


if (e == 2):# Segunda condicion, variable igual a dos
    if (a < b):# condicion, variable (a) es menor a la variable (b)
        if (a < c):# condicion, variable (a) es menor a la variable (c)
            if (b < c):# condicion, variable (b) es menor a la variable (c)
               print(a, b, c)# si esto se cumple muestre las variables(a, b, c) al usuario
            else:# de lo contrario
               print(a, c, b)# muestre las variables (a, c, b) al usuario
               
    if (c < a):# condicion, variable (c) es menor a la variable (a)
        if (c < b):# condicion, variable (c) es menor a la variable (b)
            if (b < a):# condicion, variable (b) es menor a la variable (a)
               print(c, b, a) # si esto se cumple muestre las variables (c, b, a) al usuario
            else:# de lo contrario
               print(c, a, b)# muestre las variables (c, a, b) al ausuario

    if (b < a):# condicion, variable (b) es menor a la variable (a)
        if (b < c):# condicion, variable (b) es menor a la variable (c)
            if (a < c):# condicion, variable (a) es menor a la variable (c)
               print(b, a, c) # si esto se cumple muestre las variables (b, a, c) al usuario 
            else:# de lo contrario
               print(b, c, a) # muestre las variables (b, c, a) al usuario

if (a==b): # variables (b) y (a) son iguales
    print("b y a son iguales") # muestre al usuario 
    if (a==c): # variables (a) y (c) son iguales
        print("a y c son iguales") # muestre al usuario 
    if (b==c):# variables (b) y (c) son iguales
         print(" b y c con iguales") # muestre al usuario
    if (a==b==c): # variables (a),(b)y (c) son iguales
             print("todos son iguales") # muestre al usuario
# Out:
# ingrese 3 numeros enteros diferenetes
# elija 1 si lo quiere de mayor a menor y 2 si lo quiere de menor a mayor2
# ingrese el numero a3
# ingrese el numero b2
# ingrese el numero c1
# 1 2 3

# %% [markdown]
# Ejercicio de documentacion clase 18/02/2021
